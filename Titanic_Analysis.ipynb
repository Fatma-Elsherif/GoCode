# %% [raw]
# # First Preprocessing phase.

# %%
import seaborn as sns
# %matplotlib inline
import pandas as bb
import warnings
warnings.filterwarnings("ignore")

######## importing the dataset using Pandas and showing head and info
db=bb.read_csv(r'C:\ya1\a1\titanic-passengers.csv')
db.head()
# Out:
#    PassengerId Survived  Pclass                                 Name     Sex  \
# 0          343       No       2                      Mr. Erik Gustaf    male
# 1           76       No       3                    Mr. Sigurd Hansen    male
# 2          641       No       3                       Mr. Hans Peder    male
# 3          568       No       3   Mrs. Nils (Alma Cornelia Berglund)  female
# 4          672       No       1                         Mr. Thornton    male
#
#     Age  SibSp  Parch     Fare  Cabin Embarked
# 0  28.0      0      0  13.0000    NaN        S
# 1  25.0      0      0   7.6500  F G73        S
# 2  20.0      0      0   7.8542    NaN        S
# 3  29.0      0      4  21.0750    NaN        S
# 4  31.0      1      0  52.0000    B71        S

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
db.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
db.corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare
# PassengerId     1.000000 -0.035144  0.036847 -0.057527 -0.001652  0.012658
# Pclass         -0.035144  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age             0.036847 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp          -0.057527  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch          -0.001652  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare            0.012658 -0.549500  0.096067  0.159651  0.216225  1.000000

# %% [raw]
# # preprocessdata: find missing information and replace it with the appropriate values.

# %%
#finding unique data 

print(db['Sex'].value_counts())
print(db['Age'].value_counts())
print(db['SibSp'].value_counts())
print(db['Parch'].value_counts())
print(db['Fare'].value_counts())
print(db['Embarked'].value_counts())
print(db['Survived'].value_counts())
print(db['Survived'].value_counts())
db['Survived'] = db['Survived'].str.replace('Yes', '1')
db['Survived'] = db['Survived'].str.replace('No', '0')
db['Survived']=db['Survived'].astype(str).astype(int)
db.corr()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 80.00     1
# 36.50     1
# 55.50     1
# 14.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 7.7417      1
# 8.8500      1
# 13.4167     1
# 26.3875     1
# 10.5167     1
# Name: Fare, Length: 248, dtype: int64
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
# No     549
# Yes    342
# Name: Survived, dtype: int64
# No     549
# Yes    342
# Name: Survived, dtype: int64
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# ...

# %%
# replacing nan values

db['Age'].fillna(int(db['Age'].mean()), inplace=True)
db=db.dropna()

db
# Out:
#      PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 1             76         0       3        Mr. Sigurd Hansen    male  25.0
# 4            672         0       1             Mr. Thornton    male  31.0
# 16           378         0       1         Mr. Harry Elkins    male  27.0
# 19           225         1       1   Mr. Frederick Maxfield    male  38.0
# 26           588         1       1           Mr. Maxmillian    male  60.0
# ..           ...       ...     ...                      ...     ...   ...
# 862          619         1       2      Miss. Marion Louise  female   4.0
# 863          858         1       1          Mr. Peter Denis    male  51.0
# 865          196         1       1              Miss. Elise  female  58.0
# 875          463         0       1             Mr. Arthur H    male  47.0
# 881          699         0       1         Mr. John Borland    male  49.0
#
#      SibSp  Parch      Fare  Cabin Embarked
# ...

# %%
# create a new dataset for the title
db_Name=db[['Name','Survived']]
db_Name["Name"]= db["Name"].str.split(".", n = 1, expand = True)
db_Name=db_Name.dropna()
db_Name
# Out:
#       Name Survived
# 0       Mr       No
# 1       Mr       No
# 2       Mr       No
# 3      Mrs       No
# 4       Mr       No
# ..     ...      ...
# 886    Mrs      Yes
# 887     Mr       No
# 888   Miss       No
# 889     Mr       No
# 890   Miss      Yes
#
# [891 rows x 2 columns]

# %% [raw]
# # Second visualization phase.

# %%
sns.heatmap(db.corr())
# Out:
# <AxesSubplot:>

# %% [raw]
#  studying the distribution of the most important features based on your understanding of the dataset and the problem.

# %%
sns.heatmap(db.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# use group by

# %%
db.groupby(['Embarked']).count()
# Out:
#           Sex  Age  SibSp  Parch  Fare
# Embarked
# 0         130  130    130    130   130
# 1         554  554    554    554   554
# 2          28   28     28     28    28

# %%
db.groupby(['Age']).mean()
# Out:
#        PassengerId  Survived  Pclass     SibSp     Parch        Fare
# Age
# 0.92    306.000000  1.000000     1.0  1.000000  2.000000  151.550000
# 1.00    184.000000  1.000000     2.0  2.000000  1.000000   39.000000
# 2.00    281.666667  0.333333     2.0  0.666667  1.333333   62.670833
# 3.00    194.000000  1.000000     2.0  1.000000  1.000000   26.000000
# 4.00    358.666667  1.000000     2.0  1.000000  1.333333   45.852767
# ...            ...       ...     ...       ...       ...         ...
# 64.00   439.000000  0.000000     1.0  1.000000  4.000000  263.000000
# 65.00   256.000000  0.000000     1.0  0.000000  0.500000   44.264600
# 70.00   746.000000  0.000000     1.0  1.000000  1.000000   71.000000
# 71.00    97.000000  0.000000     1.0  0.000000  0.000000   34.654200
# 80.00   631.000000  1.000000     1.0  0.000000  0.000000   30.000000
#
# [63 rows x 6 columns]

# %%
db.groupby(['Survived']).count()
# Out:
#           Sex  Age  SibSp  Parch  Fare  Embarked  Pclass
# Survived
# 0         549  549    549    549   549       549     549
# 1         340  340    340    340   340       340     340

# %%
db[['Pclass', 'Survived','Sex']].groupby(['Survived'], as_index = False).mean().sort_values('Survived', ascending = False)
# Out:
#    Survived    Pclass
# 1         1  1.186567
# 0         0  1.220588

# %% [raw]
# Visualize the correlation between Sex and Age in a plot of your choosing.

# %%
sns.boxplot(x='Age',y='Sex',hue='Survived',data=db)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %%
sns.barplot(x='Sex',y='Age',hue='Survived',data=db)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.barplot(x='Fare',y='Embarked',hue='Survived', data=db)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Embarked'>

# %%
sns.barplot(x='Embarked',y='Fare',hue='Survived',data=db)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Fare'>

# %%
sns.barplot(x='Parch',y='Fare',hue='Survived',data=db)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Fare'>

# %%
sns.barplot(x='Pclass',y='Survived',data=db)
#serviving rate is correlated to class Level
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
sns.barplot(x='Survived',y='Sex',data=db)
#more women servived than men
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Sex'>

# %%
sns.barplot(x='Survived',y='Age',data=db)
#age is not relevent
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
sns.countplot(x='Sex',data=db)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.barplot(x='Survived',y='Fare',data=db)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Fare'>

# %%
sns.barplot(x='Survived',y='Pclass',data=db)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
sns.boxplot(data=db,palette='rainbow',orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(db)

# %%
sns.pairplot(db,hue='Survived',palette='coolwarm')

# %%
sns.barplot(x='Parch',y='Sex',hue='Survived',data=db)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Sex'>

# %%
sns.barplot(x='Pclass',y='Survived',data=db)
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
db.pivot_table(values='Survived',index='Sex',columns='Pclass')
# Out:
# Pclass         1         2         3
# Sex
# female  0.962025  0.900000  0.666667
# male    0.410526  0.666667  0.333333

# %%
piv = db.pivot_table(values='Fare',index='Sex',columns=['Survived'])
sns.heatmap(piv)
#most of the men died especially those who paid law fare

#most of the wealthy women servived ,
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Sex'>

# %%
piv = db.pivot_table(values='Pclass',index='Sex',columns=['Survived'])
sns.heatmap(piv)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Sex'>

# %% [raw]
# def plot_correlation_map

# %%
def plot_correlation_map( df ):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(db)

# %% [markdown]
# Survivers :
# sex(women survived more than men, even though the women were poreginally less than men)
# Pclass(the higher the class the higher the servival rate)
# Fare (the higher the Fare the higher the the servival rate)

# %%
db['FamilySize'] =  db['Parch'] + db['SibSp']
db['FamilySize']
# Out:
# 1      0
# 4      1
# 16     2
# 19     1
# 26     2
#       ..
# 862    3
# 863    0
# 865    0
# 875    0
# 881    2
# Name: FamilySize, Length: 202, dtype: int64

# %%
db
# Out:
#      PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 1             76         0       3        Mr. Sigurd Hansen    male  25.0
# 4            672         0       1             Mr. Thornton    male  31.0
# 16           378         0       1         Mr. Harry Elkins    male  27.0
# 19           225         1       1   Mr. Frederick Maxfield    male  38.0
# 26           588         1       1           Mr. Maxmillian    male  60.0
# ..           ...       ...     ...                      ...     ...   ...
# 862          619         1       2      Miss. Marion Louise  female   4.0
# 863          858         1       1          Mr. Peter Denis    male  51.0
# 865          196         1       1              Miss. Elise  female  58.0
# 875          463         0       1             Mr. Arthur H    male  47.0
# 881          699         0       1         Mr. John Borland    male  49.0
#
#      SibSp  Parch      Fare  Cabin Embarked  FamilySize
# ...

# %%
sns.countplot('FamilySize',data=db,palette='Blues')
# Out:
# <AxesSubplot:xlabel='FamilySize', ylabel='count'>

# %%
#db_Name['Name']=db_Name['Name'].split('.')
db_Name=db[['Name','Survived']]

db_Name["Name"]= db["Name"].str.split(".", n = 1, expand = True)
db_Name["Name"]= db_Name["Name"].str.strip()
db_Name
# Out:
#      Name  Survived
# 1      Mr         0
# 4      Mr         0
# 16     Mr         0
# 19     Mr         1
# 26     Mr         1
# ..    ...       ...
# 862  Miss         1
# 863    Mr         1
# 865  Miss         1
# 875    Mr         0
# 881    Mr         0
#
# [202 rows x 2 columns]

# %%
Title_Dictionary = {"the Countess":"Royalty","Dr":"Officer","Capt":"Officer","Col":"Officer","Dona":"Royalty","Jonkheer":"Royalty","Major":"Officer","Master":"Master","Miss":"Miss","Mlle": "Miss","Mme":"Miss","Mr":"M","Mrs":"Mrs","Ms":"Mrs","Rev":"Officer","Sir":"Royalty","Don":"Royalty"}
db_Name=db[['Name','Survived']]

db_Name["Name"]= db["Name"].str.split(".", n = 1, expand = True)
db_Name["Name"]= db_Name["Name"].str.strip()
db_Name=db_Name.replace({'Name': Title_Dictionary})
db_Count=db_Name.groupby(['Name']).count()
db_Count
# Out:
#          Survived
# Name
# Lady            1
# M              93
# Master          7
# Miss           49
# Mrs            43
# Officer         7
# Royalty         2

# %%
db_Name['per'] = db_Name.groupby('Name').Survived.transform('count')

# %%
db_Name
# Out:
#      Name  Survived
# 1       M         0
# 4       M         0
# 16      M         0
# 19      M         1
# 26      M         1
# ..    ...       ...
# 862  Miss         1
# 863     M         1
# 865  Miss         1
# 875     M         0
# 881     M         0
#
# [202 rows x 2 columns]

# %%
sns.countplot('Name',data=db_Name,palette='Blues')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='count'>

# %%
db_Name['Survived'] = db_Name['Survived'].str.replace('Yes', '1')
db_Name['Survived'] = db_Name['Survived'].str.replace('No', '0')
db_Name['Survived']=db_Name['Survived'].astype(str).astype(int)

# %%
sns.barplot(x='Name',hue='per',y='Survived',data=db_Name)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Survived'>

# %%
sns.distplot(db_Name[['Survived','per']],bins=30)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.jointplot(x='Name',y='per',data=db_Name,kind='scatter')

# %%
sns.jointplot(x='Sex',y='Age',data=db,kind='reg')

# %%
sns.pairplot(db,hue='Age')

# %%
sns.relplot(x="Name", y="per", hue="Survived",style="per", col="Survived", data=db_Name)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(db_Name['Name'], label='Group A')

plt.plot(db_Name['Survived'], label='Group B')

plt.legend()

plt.show()

# %%
sns.countplot(x='Survived', data=db_Name)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Name', data=db_Name)
db_Ser=[]

db_Ser['Survived']=db_Name.iloc[db_Name['Survived'] == 1] 
db_Ser['Name']=loc[db_Name['Name']] 
db_Ser
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-295-85110db846b4> in <module>
#       2 db_Ser=[]
#       3
# ----> 4 db_Ser['Survived']=db_Name.iloc[db_Name['Survived'] == 1]
#       5 db_Ser['Name']=loc[db_Name['Name']]
#       6 db_Ser
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1480
#    1481         if com.is_bool_indexer(key):
# -> 1482             self._validate_key(key, axis)
#    1483             return self._getbool_axis(key, axis=axis)
#    1484
#
# ...

# %%
def plot_correlation_map( df ):
    import matplotlib.pyplot as plt
    # %matplotlib inline
    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map(db_Name)
#where is the names?

# %% [markdown]
# most of the men died
# nearly half the workers died
# all the royalities and the ladies survived
# only few of the women of Mrs and Miss died
