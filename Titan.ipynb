# %%
import seaborn as sns
get_ipython().run_line_magic('matplotlib', 'inline')
import pandas as bb

db=bb.read_csv(r'C:\ya1\a1\titanic-passengers.csv')

# %%
db=bb.read_csv(r'C:\ya1\a1\titanic-passengers.csv')
db=db[['Sex','Age','SibSp','Parch','Fare','Embarked']]
db
# Out:
#         Sex   Age  SibSp  Parch     Fare Embarked
# 0      male  28.0      0      0  13.0000        S
# 1      male  25.0      0      0   7.6500        S
# 2      male  20.0      0      0   7.8542        S
# 3    female  29.0      0      4  21.0750        S
# 4      male  31.0      1      0  52.0000        S
# ..      ...   ...    ...    ...      ...      ...
# 886  female  14.0      1      0  30.0708        C
# 887    male  22.0      0      0   7.2292        C
# 888  female  30.0      0      0   8.6625        S
# 889    male   NaN      0      0   7.8958        S
# 890  female  19.0      0      0  26.0000        S
#
# [891 rows x 6 columns]

# %%
print(db['Sex'].value_counts())
print(db['Age'].value_counts())
print(db['SibSp'].value_counts())
print(db['Parch'].value_counts())
print(db['Fare'].value_counts())
print(db['Embarked'].value_counts())
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 80.00     1
# 36.50     1
# 55.50     1
# 14.50     1
# 0.42      1
# Name: Age, Length: 88, dtype: int64
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 7.7417      1
# 8.8500      1
# 13.4167     1
# 26.3875     1
# 10.5167     1
# Name: Fare, Length: 248, dtype: int64
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
db.corr()
# Out:
#             Age     SibSp     Parch      Fare
# Age    1.000000 -0.308247 -0.189119  0.096067
# SibSp -0.308247  1.000000  0.414838  0.159651
# Parch -0.189119  0.414838  1.000000  0.216225
# Fare   0.096067  0.159651  0.216225  1.000000

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sex       891 non-null    object
#  1   Age       714 non-null    float64
#  2   SibSp     891 non-null    int64
#  3   Parch     891 non-null    int64
#  4   Fare      891 non-null    float64
#  5   Embarked  889 non-null    object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 41.9+ KB

# %%
db['Age'].fillna(int(db['Age'].mean()), inplace=True)

db=db.dropna()
db
# Out:
#         Sex   Age  SibSp  Parch     Fare Embarked
# 0      male  28.0      0      0  13.0000        S
# 1      male  25.0      0      0   7.6500        S
# 2      male  20.0      0      0   7.8542        S
# 3    female  29.0      0      4  21.0750        S
# 4      male  31.0      1      0  52.0000        S
# ..      ...   ...    ...    ...      ...      ...
# 886  female  14.0      1      0  30.0708        C
# 887    male  22.0      0      0   7.2292        C
# 888  female  30.0      0      0   8.6625        S
# 889    male  29.0      0      0   7.8958        S
# 890  female  19.0      0      0  26.0000        S
#
# [889 rows x 6 columns]

# %%
import numpy as np

db['Embarked'] = db['Embarked'].str.replace('S', '1')
db['Embarked'] = db['Embarked'].str.replace('C', '0')
db['Embarked'] = db['Embarked'].str.replace('Q', '2')
db['Embarked']=db['Embarked'].astype(str).astype(int)


db['Sex'] = db['Sex'].str.replace('female', '1')
db['Sex'] = db['Sex'].str.replace('male', '0')


db['Sex']=db['Sex'].astype(str).astype(int)
db.corr()
# Out:
# <ipython-input-7-5110c4e1dbd3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['Embarked'] = db['Embarked'].str.replace('S', '1')
# <ipython-input-7-5110c4e1dbd3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['Embarked'] = db['Embarked'].str.replace('C', '0')
# <ipython-input-7-5110c4e1dbd3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['Embarked'] = db['Embarked'].str.replace('Q', '2')
# <ipython-input-7-5110c4e1dbd3>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['Embarked']=db['Embarked'].astype(str).astype(int)
# <ipython-input-7-5110c4e1dbd3>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['Sex'] = db['Sex'].str.replace('female', '1')
# <ipython-input-7-5110c4e1dbd3>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['Sex'] = db['Sex'].str.replace('male', '0')
# <ipython-input-7-5110c4e1dbd3>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['Sex']=db['Sex'].astype(str).astype(int)
#                Sex       Age     SibSp     Parch      Fare  Embarked
# Sex       1.000000 -0.088257  0.116348  0.247508  0.179958 -0.023175
# Age      -0.088257  1.000000 -0.232227 -0.175512  0.090736 -0.036169
# SibSp     0.116348 -0.232227  1.000000  0.414542  0.160887  0.031095
# Parch     0.247508 -0.175512  0.414542  1.000000  0.217532 -0.035756
# Fare      0.179958  0.090736  0.160887  0.217532  1.000000 -0.269588
# Embarked -0.023175 -0.036169  0.031095 -0.035756 -0.269588  1.000000

# %%
sns.heatmap(db.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(db.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
db.groupby(['Embarked']).count()
# Out:
#           Sex  Age  SibSp  Parch  Fare
# Embarked
# 0         168  168    168    168   168
# 1         644  644    644    644   644
# 2          77   77     77     77    77

# %%
db.groupby(['Sex']).count()
# Out:
#      Age  SibSp  Parch  Fare  Embarked
# Sex
# 0    577    577    577   577       577
# 1    312    312    312   312       312

# %%
db.groupby(level=0).mean()
# Out:
#      Sex   Age  SibSp  Parch     Fare  Embarked
# 0      0  28.0      0      0  13.0000         1
# 1      0  25.0      0      0   7.6500         1
# 2      0  20.0      0      0   7.8542         1
# 3      1  29.0      0      4  21.0750         1
# 4      0  31.0      1      0  52.0000         1
# ..   ...   ...    ...    ...      ...       ...
# 886    1  14.0      1      0  30.0708         0
# 887    0  22.0      0      0   7.2292         0
# 888    1  30.0      0      0   8.6625         1
# 889    0  29.0      0      0   7.8958         1
# 890    1  19.0      0      0  26.0000         1
#
# [889 rows x 6 columns]

# %%
sns.barplot(x='Embarked',y='Sex',data=db)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Sex'>

# %%
sns.barplot(x='Fare',y='Embarked',data=db)
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Embarked'>

# %%
sns.barplot(x='Embarked',y='Fare',data=db)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Fare'>

# %%
sns.barplot(x='Parch',y='Fare',data=db)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Fare'>

# %%
sns.countplot(x='Sex',data=db)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
sns.boxplot(x="Fare", y="Embarked", data=db,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Embarked'>

# %%
sns.boxplot(data=db,palette='rainbow',orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(db['Fare'],kde=False,bins=30)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare'>

# %%
sns.jointplot(x='Fare',y='Embarked',data=db,kind='scatter')

# %%
sns.pairplot(db)

# %%
sns.pairplot(db,hue='Embarked',palette='coolwarm')

# %%
sns.barplot(x='Parch',y='Fare',data=db)
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='Fare'>

# %%
db.pivot_table(values='Parch',index='Sex',columns=['Embarked'])
# Out:
# Embarked         0         1         2
# Sex
# 0         0.263158  0.240363  0.121951
# 1         0.493151  0.788177  0.222222

# %%
piv = db.pivot_table(values='Fare',index='Sex',columns=['Embarked'])

# %%
sns.heatmap(piv)
#most of the men died especially thouth with law fare
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Sex'>

# %%
piv = db.pivot_table(values='Parch',index='Sex',columns=['Embarked'])
sns.heatmap(piv)
#most of the welthy women servived ,
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='Sex'>

# %%
db['Fare'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
db['Parch'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
db['Embarked'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
