# %%
import seaborn as sns
# %matplotlib inline
import pandas as bb

db=bb.read_csv(r'C:\ya1\a1\auto_mpg_dataset.csv')
db.info()
db.isnull().sum() 
db.dropna(subset=['origin'],inplace=True) 
db
db.dropna(subset=['mpg'],inplace=True) 
db
db.drop('horsepower', axis=1, inplace=True)
db
db['model_year'].value_counts()

x=bb.get_dummies(db['horsepower'])
x
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cylinders     398 non-null    int64
#  1   displacement  398 non-null    float64
#  2   horsepower    398 non-null    float64
#  3   weight        398 non-null    float64
#  4   acceleration  398 non-null    float64
#  5   model_year    398 non-null    int64
#  6   origin        398 non-null    int64
#  7   car_name      398 non-null    object
#  8   mpg           398 non-null    float64
# dtypes: float64(5), int64(3), object(1)
# memory usage: 28.1+ KB
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# ...

# %%
import seaborn as sns
# %matplotlib inline
import pandas as bb

db=bb.read_csv(r'c:\ya1\a1\auto_mpg_dataset.csv')
db.isnull().sum() 
db.dropna(subset=['origin'],inplace=True) 
db
db.dropna(subset=['model_year'],inplace=True) 
db
db.drop('acceleration', axis=1, inplace=True)
db
db['weight'].value_counts()
db['horsepower'].value_counts()
db['displacement'].value_counts()
# Out:
# 97.0     21
# 98.0     18
# 350.0    18
# 250.0    17
# 318.0    17
#          ..
# 68.0      1
# 155.0     1
# 96.0      1
# 97.5      1
# 114.0     1
# Name: displacement, Length: 82, dtype: int64

# %%
db.corr()
# Out:
#               cylinders  displacement  horsepower    weight  model_year  \
# cylinders      1.000000      0.950721    0.084291  0.896017   -0.348746
# displacement   0.950721      1.000000    0.079333  0.932824   -0.370164
# horsepower     0.084291      0.079333    1.000000  0.071114   -0.067952
# weight         0.896017      0.932824    0.071114  1.000000   -0.306564
# model_year    -0.348746     -0.370164   -0.067952 -0.306564    1.000000
# origin        -0.562543     -0.609409    0.035575 -0.581024    0.180662
# mpg           -0.775396     -0.804203   -0.073501 -0.831741    0.579267
#
#                 origin       mpg
# cylinders    -0.562543 -0.775396
# displacement -0.609409 -0.804203
# horsepower    0.035575 -0.073501
# weight       -0.581024 -0.831741
# model_year    0.180662  0.579267
# origin        1.000000  0.563450
# mpg           0.563450  1.000000

# %%
sns.heatmap(db.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(db.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
db.describe()
# Out:
#         cylinders  displacement     horsepower       weight  model_year  \
# count  398.000000    398.000000     398.000000   398.000000  398.000000
# mean     5.454774    193.425879   -1404.643216  2970.424623   76.010050
# std      1.701004    104.269838   12213.424763   846.841774    3.697627
# min      3.000000     68.000000 -100000.000000  1613.000000   70.000000
# 25%      4.000000    104.250000      75.000000  2223.750000   73.000000
# 50%      4.000000    148.500000      92.000000  2803.500000   76.000000
# 75%      8.000000    262.000000     125.000000  3608.000000   79.000000
# max      8.000000    455.000000     230.000000  5140.000000   82.000000
#
#            origin         mpg
# count  398.000000  398.000000
# mean     1.572864   23.514573
# std      0.802055    7.815984
# min      1.000000    9.000000
# 25%      1.000000   17.500000
# 50%      1.000000   23.000000
# 75%      2.000000   29.000000
# max      3.000000   46.600000

# %%
db.groupby(['model_year']).count()
# Out:
#             cylinders  displacement  horsepower  weight  origin  car_name  mpg
# model_year
# 70                 29            29          29      29      29        29   29
# 71                 28            28          28      28      28        28   28
# 72                 28            28          28      28      28        28   28
# 73                 40            40          40      40      40        40   40
# 74                 27            27          27      27      27        27   27
# 75                 30            30          30      30      30        30   30
# 76                 34            34          34      34      34        34   34
# 77                 28            28          28      28      28        28   28
# 78                 36            36          36      36      36        36   36
# 79                 29            29          29      29      29        29   29
# 80                 29            29          29      29      29        29   29
# ...

# %%
sns.barplot(x='weight',y='mpg',data=db)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %%
sns.barplot(x='model_year',y='mpg',data=db)
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='mpg'>

# %%
sns.barplot(x='horsepower',y='origin',data=db)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='origin'>

# %%
sns.countplot(x='horsepower',data=db)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='count'>

# %%
sns.countplot(x='model_year',data=db)
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='count'>

# %%
sns.boxplot(x="model_year", y="horsepower", data=db,palette='rainbow')
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='horsepower'>

# %%
sns.boxplot(data=db,palette='rainbow',orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.distplot(db['horsepower'],kde=False,bins=30)
# Out:
# <AxesSubplot:xlabel='horsepower'>

# %%
sns.jointplot(x='horsepower',y='displacement',data=db,kind='scatter')

# %%
sns.pairplot(db)

# %%
sns.pairplot(db,hue='model_year',palette='coolwarm')

# %%
db.pivot_table(values='Survived',index='Sex',columns=['Pclass'])
# Out:
# Pclass         1         2         3
# Sex
# female  0.964706  0.918919  0.460784
# male    0.396040  0.151515  0.150198

# %%
piv = db.pivot_table(values='cylinders',index='displacement',columns=['mpg'])
sns.heatmap(piv)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='displacement'>

# %%
x=bb.get_dummies(db['Sex'])
x
db['Fare'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
